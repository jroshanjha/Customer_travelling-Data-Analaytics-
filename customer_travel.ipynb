# %%
import numpy as np  # For Data numerical Operations such as Array or Matrics 
import pandas as pd # For Data Manipulation such Modify operation on etc dataset
import matplotlib.pyplot as plt # For Data Vislualtion 
import seaborn as sns # For Data Vislualtion
import warnings
warnings.filterwarnings('ignore')
# Ignore Warnings

# %matplotlib inline

# %%
# Load Data Customer travel Dataset ...... 
data = pd.read_csv("data/Customertravel.csv")
data.head()
# Out:
#    Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0   34            No     Middle Income              6
# 1   34           Yes        Low Income              5
# 2   37            No     Middle Income              3
# 3   30            No     Middle Income              2
# 4   30            No        Low Income              1
#
#   AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                         No              Yes       0
# 1                        Yes               No       1
# 2                        Yes               No       0
# 3                         No               No       0
# 4                         No               No       0

# %%
data.transform
# Out:
# <bound method DataFrame.transform of      Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0     34            No     Middle Income              6
# 1     34           Yes        Low Income              5
# 2     37            No     Middle Income              3
# 3     30            No     Middle Income              2
# 4     30            No        Low Income              1
# ..   ...           ...               ...            ...
# 949   31           Yes        Low Income              1
# 950   30            No     Middle Income              5
# 951   37            No     Middle Income              4
# 952   30            No        Low Income              1
# 953   31           Yes       High Income              1
#
#     AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                           No              Yes       0
# 1                          Yes               No       1
# 2                          Yes               No       0
# ...

# %%
data.size  # Total 6678 ( 954 rows * 7 columns ) number of values presents in dataset....
# Out:
# 6678

# %%
data.isnull().sum()  # No Any Records as null which presents in dataset
# Out:
# Age                           0
# FrequentFlyer                 0
# AnnualIncomeClass             0
# ServicesOpted                 0
# AccountSyncedToSocialMedia    0
# BookedHotelOrNot              0
# Target                        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    object
#  2   AnnualIncomeClass           954 non-null    object
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    object
#  5   BookedHotelOrNot            954 non-null    object
#  6   Target                      954 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 52.3+ KB

# %%
data.describe()  # For Statistical Analaytics
# Out:
#               Age  ServicesOpted      Target
# count  954.000000     954.000000  954.000000
# mean    32.109015       2.437107    0.234801
# std      3.337388       1.606233    0.424097
# min     27.000000       1.000000    0.000000
# 25%     30.000000       1.000000    0.000000
# 50%     31.000000       2.000000    0.000000
# 75%     35.000000       4.000000    0.000000
# max     38.000000       6.000000    1.000000

# %%
print(np.mean(data.Age))   # mean of Age Columns 

print(np.mean(data.ServicesOpted)) # Mean of ServicesOpted Columns

print(np.mean(data.Target)) # Mean of Target Columns
# Out:
# 32.109014675052414
# 2.4371069182389937
# 0.2348008385744235

# %%
print(np.std(data.Age))   # Standard Deviations of Age Columns 

print(np.std(data.ServicesOpted)) # Standard Deviations of ServicesOpted Columns

print(np.std(data.Target)) # Standard Deviations of Target Columns
# Out:
# 3.3356379570477115
# 1.605391340932558
# 0.4238742794498989

# %%
sns.displot(data.Age,kind='kde')

# %%
sns.histplot(data.Age,kde =True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.displot(data.ServicesOpted,kind='kde')

# %%
sns.histplot(data.ServicesOpted,kde =True,color='blue',edgecolor='red',linestyle='-')
# Out:
# <Axes: xlabel='ServicesOpted', ylabel='Count'>

# %%
sns.displot(data.Target,kind='kde')

# %%
sns.histplot(data.Target,kde =True,color='blue',edgecolor='red',linestyle='-')
# Out:
# <Axes: xlabel='Target', ylabel='Count'>

# %%
print(np.min(data.Age))   # minimun Records of Age Columns 

print(np.min(data.ServicesOpted)) # Minimum Records of ServicesOpted Columns

print(np.min(data.Target)) # Minimum Records of Target Columns
# Out:
# 27
# 1
# 0

# %%
print(np.percentile(data.Age,25))   # 25% percentile of Age Columns 

print(np.percentile(data.ServicesOpted,25)) # 25% percentile of ServicesOpted Columns

print(np.percentile(data.Target,25)) # 25% percentile of Target Columns
# Out:
# 30.0
# 1.0
# 0.0

# %%
print(np.percentile(data.Age,50))   # 50% percentile of Age Columns 

print(np.percentile(data.ServicesOpted,50)) # 50% percentile of ServicesOpted Columns

print(np.percentile(data.Target,50)) # 50% percentile of Target Columns
# Out:
# 31.0
# 2.0
# 0.0

# %%
print(np.percentile(data.Age,75))   # 75% percentile of Age Columns 

print(np.percentile(data.ServicesOpted,75)) # 75% percentile of ServicesOpted Columns

print(np.percentile(data.Target,75)) # 75% percentile of Target Columns
# Out:
# 35.0
# 4.0
# 0.0

# %%
print(np.max(data.Age))   # Maximun Records of Age Columns 

print(np.max(data.ServicesOpted)) # Maximun Records of ServicesOpted Columns

print(np.max(data.Target)) # Maximun Records of Target Columns
# Out:
# 38
# 6
# 1

# %%
# Group data and compute statistics
grouped = data.groupby('Age')['ServicesOpted'].mean()
grouped
# Out:
# Age
# 27    2.387097
# 28    2.619718
# 29    2.514286
# 30    2.538136
# 31    2.077670
# 33    2.206897
# 34    2.514019
# 35    2.442308
# 36    2.253731
# 37    2.531746
# 38    2.322581
# Name: ServicesOpted, dtype: float64

# %%
# Group data and compute statistics
grouped = data.groupby('Age')['Target'].mean()
grouped
# Out:
# Age
# 27    0.564516
# 28    0.563380
# 29    0.185714
# 30    0.144068
# 31    0.145631
# 33    0.275862
# 34    0.186916
# 35    0.250000
# 36    0.238806
# 37    0.214286
# 38    0.096774
# Name: Target, dtype: float64

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data[data['Age'] < 35]

data[(data['Age'] < 35) & (data['Age']>30)]
# Out:
#      Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0     34            No     Middle Income              6
# 1     34           Yes        Low Income              5
# 6     34            No     Middle Income              4
# 7     34            No        Low Income              2
# 10    34            No        Low Income              1
# ..   ...           ...               ...            ...
# 939   34           Yes        Low Income              2
# 943   31            No        Low Income              2
# 948   31            No     Middle Income              1
# 949   31           Yes        Low Income              1
# 953   31           Yes       High Income              1
#
#     AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                           No              Yes       0
# 1                          Yes               No       1
# 6                          Yes              Yes       0
# 7                          Yes               No       1
# ...

# %%
data[(data['ServicesOpted'] < 5) & (data['ServicesOpted']>1)]
# Out:
#      Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 2     37            No     Middle Income              3
# 3     30            No     Middle Income              2
# 6     34            No     Middle Income              4
# 7     34            No        Low Income              2
# 8     30            No        Low Income              3
# ..   ...           ...               ...            ...
# 939   34           Yes        Low Income              2
# 943   31            No        Low Income              2
# 944   36            No     Middle Income              4
# 947   38     No Record     Middle Income              2
# 951   37            No     Middle Income              4
#
#     AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 2                          Yes               No       0
# 3                           No               No       0
# 6                          Yes              Yes       0
# 7                          Yes               No       1
# ...

# %%
#Changed Object or String into Numerical or categorical for dataanalaytics....
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    object
#  2   AnnualIncomeClass           954 non-null    object
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    object
#  5   BookedHotelOrNot            954 non-null    object
#  6   Target                      954 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 52.3+ KB

# %%
data.FrequentFlyer.unique()
# Out:
# array(['No', 'Yes', 'No Record'], dtype=object)

# %%
data.AnnualIncomeClass.unique()
# Out:
# array(['Middle Income', 'Low Income', 'High Income'], dtype=object)

# %%
data.AccountSyncedToSocialMedia.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data.BookedHotelOrNot.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['FrequentFlyer'] = data['FrequentFlyer'].map({'No':0,'Yes':1,'No Record':2})
data['AnnualIncomeClass'] = data['AnnualIncomeClass'].map({'Middle Income':0,'Low Income':1,'High Income':2})
# data['FrequentFlyer'].value_counts()
data['AccountSyncedToSocialMedia'] = data['AccountSyncedToSocialMedia'].map({'No':0,'Yes':1})

data['BookedHotelOrNot'] = data['BookedHotelOrNot'].map({'Yes':1,'No':0})

# %%
data.head()
# Out:
#    Age  FrequentFlyer  AnnualIncomeClass  ServicesOpted  \
# 0   34              0                  0              6
# 1   34              1                  1              5
# 2   37              0                  0              3
# 3   30              0                  0              2
# 4   30              0                  1              1
#
#    AccountSyncedToSocialMedia  BookedHotelOrNot  Target
# 0                           0                 1       0
# 1                           1                 0       1
# 2                           1                 0       0
# 3                           0                 0       0
# 4                           0                 0       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    int64
#  2   AnnualIncomeClass           954 non-null    int64
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    int64
#  5   BookedHotelOrNot            954 non-null    int64
#  6   Target                      954 non-null    int64
# dtypes: int64(7)
# memory usage: 52.3 KB

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
plt.scatter(x='Age',y='BookedHotelOrNot',data=data)

# %%
sns.histplot(x='Age',y='BookedHotelOrNot',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='BookedHotelOrNot'>

# %%
sns.barplot(x='Age',y='BookedHotelOrNot',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='BookedHotelOrNot'>

# %%
sns.barplot(x='Age',y='ServicesOpted',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='ServicesOpted'>

# %%
sns.barplot(x='Age',y='FrequentFlyer',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='FrequentFlyer'>

# %%
sns.barplot(x='Age',y='AnnualIncomeClass',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='AnnualIncomeClass'>

# %%
sns.barplot(x='Age',y='AccountSyncedToSocialMedia',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='AccountSyncedToSocialMedia'>

# %%
sns.barplot(x='Age',y='BookedHotelOrNot',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='BookedHotelOrNot'>

# %%
sns.barplot(x='Age',y='Target',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Target'>

# %%
sns.countplot(x='Target',data=data)  # 'Yes':1,'No':0
# Out:
# <Axes: xlabel='Target', ylabel='count'>

# %%
sns.countplot(x='BookedHotelOrNot',data =data)  # 'No':0,'Yes':1
# Out:
# <Axes: xlabel='BookedHotelOrNot', ylabel='count'>

# %%
sns.countplot(x='AccountSyncedToSocialMedia',data =data)
# Out:
# <Axes: xlabel='AccountSyncedToSocialMedia', ylabel='count'>

# %%
sns.countplot(x='FrequentFlyer',data=data) # 'No':0,'Yes':1,'No Record':2
# Out:
# <Axes: xlabel='FrequentFlyer', ylabel='count'>

# %%
sns.countplot(x='AnnualIncomeClass',data=data) # 'Middle Income':0,'Low Income':1,'High Income':2
# Out:
# <Axes: xlabel='AnnualIncomeClass', ylabel='count'>

# %%
sns.countplot(x='Age',data = data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
ax = sns.countplot(x='Age',data = data) 
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sns.countplot(x='ServicesOpted',data = data,hue='Age')
# Out:
# <Axes: xlabel='ServicesOpted', ylabel='count'>

# %%
ax = sns.countplot(x='ServicesOpted',data = data) 
for bars in ax.containers:
    ax.bar_label(bars)

# %%
data.columns
# Out:
# Index(['Age', 'FrequentFlyer', 'AnnualIncomeClass', 'ServicesOpted',
#        'AccountSyncedToSocialMedia', 'BookedHotelOrNot', 'Target'],
#       dtype='object')

# %%
data.head()
# Out:
#    Age  FrequentFlyer  AnnualIncomeClass  ServicesOpted  \
# 0   34              0                  0              6
# 1   34              1                  1              5
# 2   37              0                  0              3
# 3   30              0                  0              2
# 4   30              0                  1              1
#
#    AccountSyncedToSocialMedia  BookedHotelOrNot  Target
# 0                           0                 1       0
# 1                           1                 0       1
# 2                           1                 0       0
# 3                           0                 0       0
# 4                           0                 0       0

# %%
df = data.groupby(['Age'],as_index=False)['ServicesOpted'].sum().sort_values(by='ServicesOpted',ascending=False)
df
# Out:
#     Age  ServicesOpted
# 3    30            599
# 9    37            319
# 6    34            269
# 4    31            214
# 1    28            186
# 2    29            176
# 8    36            151
# 0    27            148
# 7    35            127
# 10   38             72
# 5    33             64

# %%
#df = data.groupby(['Age'],as_index=False)
# sns.barplot(df,data =df)

# %%
# Generate random colors for the bars
num_bars = len(df)
colors = np.random.rand(num_bars, 3)  # Generate random RGB colors

# Plot the bar plot
plt.figure(figsize=(8, 6))
plt.bar(df['Age'], df['ServicesOpted'],color=colors)
plt.xlabel('Age')
plt.ylabel('Sum of ServicesOpted')
plt.title('Sum of ServicesOpted by Age')
plt.xticks(rotation=90)
plt.show()

# %%
df = data.groupby(['Age'],as_index=False)['FrequentFlyer'].sum().sort_values(by='FrequentFlyer',ascending=False)
df
# Out:
#     Age  FrequentFlyer
# 3    30             97
# 6    34             52
# 9    37             43
# 4    31             42
# 8    36             32
# 1    28             31
# 2    29             29
# 0    27             28
# 7    35             21
# 5    33             16
# 10   38             15

# %%
df = data.groupby(['Age'],as_index=False)['AnnualIncomeClass'].sum().sort_values(by='AnnualIncomeClass',ascending=False)
df
# Out:
#     Age  AnnualIncomeClass
# 3    30                172
# 6    34                 85
# 4    31                 81
# 9    37                 80
# 2    29                 57
# 1    28                 55
# 8    36                 47
# 0    27                 46
# 7    35                 33
# 5    33                 29
# 10   38                 19

# %%
df = data.groupby(['Age'],as_index=False)['AccountSyncedToSocialMedia'].sum().sort_values(by='AccountSyncedToSocialMedia',ascending=False)
df
# Out:
#     Age  AccountSyncedToSocialMedia
# 3    30                          97
# 9    37                          48
# 6    34                          44
# 4    31                          33
# 2    29                          28
# 1    28                          25
# 0    27                          22
# 8    36                          21
# 7    35                          18
# 5    33                          15
# 10   38                           9

# %%
df = data.groupby(['Age'],as_index=False)['BookedHotelOrNot'].sum().sort_values(by='BookedHotelOrNot',ascending=False)
df
# Out:
#     Age  BookedHotelOrNot
# 3    30                93
# 9    37                51
# 6    34                46
# 4    31                44
# 1    28                28
# 2    29                24
# 7    35                22
# 8    36                22
# 0    27                21
# 10   38                14
# 5    33                13

# %%
df = data.groupby(['Age'],as_index=False)['Target'].sum().sort_values(by='Target',ascending=False)
df
# Out:
#     Age  Target
# 1    28      40
# 0    27      35
# 3    30      34
# 9    37      27
# 6    34      20
# 8    36      16
# 4    31      15
# 2    29      13
# 7    35      13
# 5    33       8
# 10   38       3

# %%
data['Age'].hist()
# Out:
# <Axes: >

# %%
# Plot the pie chart
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgray']
# colors=colors
fig, ax = plt.subplots(figsize=(12, 10))
ax.pie(df['Age'], labels=df['Age'], autopct='%1.1f%%',startangle=90, pctdistance=0.85, labeldistance=1.1)
ax.axis('equal')  # Ensure the pie chart is circular
ax.set_title('Distribution of FrequentFlyer by Age')
plt.show()

# %%
data.head()
# Out:
#    Age  FrequentFlyer  AnnualIncomeClass  ServicesOpted  \
# 0   34              0                  0              6
# 1   34              1                  1              5
# 2   37              0                  0              3
# 3   30              0                  0              2
# 4   30              0                  1              1
#
#    AccountSyncedToSocialMedia  BookedHotelOrNot  Target
# 0                           0                 1       0
# 1                           1                 0       1
# 2                           1                 0       0
# 3                           0                 0       0
# 4                           0                 0       0

# %%
# Conclusion About All Visualazation ...

''' 
The Age of 37 and 34 Travellig Customer is well for FrequentlyFlyer when Target is 1 

and Hotel have booked..

'''
# Out:
# ' \nThe Age of 37 and 34 Travellig Customer is well for FrequentlyFlyer when Target is 1 \n\nand Hotel have booked..\n\n'

# %%
from pandas_profiling import ProfileReport 

profile = ProfileReport(data,explorative=True,dark_mode=True, title="Pandas Profiling Report")

profile.to_file(('Result.html'))
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<?, ?it/s]
